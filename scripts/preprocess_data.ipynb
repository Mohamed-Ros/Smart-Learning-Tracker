# %%
import pandas as pd
import os

# %%
os.makedirs("data/processed", exist_ok=True)

df = pd.read_csv("data/raw/fake_dataset.csv")

# %%
df['watched'] = df['watched'].astype(int)

df['mistake_type'] = df['mistake_type'].fillna("none")

# %%
df.to_csv("data/processed/preprocessed_data.csv", index=False)
print("Preprocessed Data saved: data/processed/preprocessed_data.csv")
# Out:
# Preprocessed Data saved: data/processed/preprocessed_data.csv
